# %%
from contrasttransferfunction.spectrumhelpers import downscale_spectrum, adjust_central_cross, subtract_baseline, cosine_highpass, radial_average, radial_average_old
import matplotlib.pyplot as plt
import numpy as np

# %%
spectrum = np.load("../tests/test_data/spectrum.npy")
plt.imshow(spectrum, cmap="gray")
spectrum = spectrum.astype(np.float32)
print(spectrum.max())
# Out:
# 32000.0

# %%
s2 = downscale_spectrum(spectrum, 512)
plt.imshow(s2,cmap="gray")

# %%
a = adjust_central_cross(s2)

# %%
plt.imshow(a,cmap="gray")

# %%
b = subtract_baseline(a)

# %%
plt.imshow(b,cmap="gray")

# %%
c= cosine_highpass(b,pixel_size_angstroms=4.24)

# %%
plt.imshow(c,cmap="gray")

# %%
plt.plot(radial_average(c))
# Out:
# 361.3315651863258
# 361

# %%
plt.plot(radial_average_old(c))
# Out:
# 362.03867196751236
# 362.0
